# %%
from nltk.stem import WordNetLemmatizer#has dictionary of words,root word which will have meaning
words=["eating","eats","eaten","writing","writes","programming","programs","history","fairly"]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nandanamk\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
#stopwords
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
nltk.download('stopwords')#to be removed
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nandanamk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
# ...

# %%
from nltk.stem import PorterStemmer

stemmer=PorterStemmer()

para='''Students are studying various subjects at universities while researchers are analyzing data and developing innovative technologies. Several organizations are working on improving healthcare systems, reducing environmental pollution, and creating sustainable solutions for future generations. People communicate through different platforms, sharing ideas, learning new skills, and collaborating on projects. Advances in science and engineering are transforming industries, enabling businesses to operate more efficiently and helping communities solve complex problems.'''
stop=stopwords.words('english')

sentences=nltk.sent_tokenize(para)

#stemming after removing stop words

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    print([stemmer.stem(word) for word in words if word not in set(stop)])
    sentences[i]=' '.join(words)

print(sentences)
# Out:
# ['student', 'studi', 'variou', 'subject', 'univers', 'research', 'analyz', 'data', 'develop', 'innov', 'technolog', '.']
# ['sever', 'organ', 'work', 'improv', 'healthcar', 'system', ',', 'reduc', 'environment', 'pollut', ',', 'creat', 'sustain', 'solut', 'futur', 'gener', '.']
# ['peopl', 'commun', 'differ', 'platform', ',', 'share', 'idea', ',', 'learn', 'new', 'skill', ',', 'collabor', 'project', '.']
# ['advanc', 'scienc', 'engin', 'transform', 'industri', ',', 'enabl', 'busi', 'oper', 'effici', 'help', 'commun', 'solv', 'complex', 'problem', '.']
# ...

# %%
#pos
