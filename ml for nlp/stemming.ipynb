# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()#changing words to meaningless stem words

words=["eating","eats","eaten","writing","writes","programming","programs","history"]

for word in words:
    print(word+"-->"+stemming.stem(word))
# Out:
# eating-->eat
# eats-->eat
# eaten-->eaten
# writing-->write
# writes-->write
# programming-->program
# programs-->program
# history-->histori

# %%
from nltk.stem import RegexpStemmer

reg_stemmer=RegexpStemmer('ing$|s$|able$',min=4)

reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
#Snowball Stemmer
from nltk.stem import SnowballStemmer

snow_stemmer=SnowballStemmer('english')

for word in words:
    print(word+"-->"+snow_stemmer.stem(word))
# Out:
# eating-->eat
# eats-->eat
# eaten-->eaten
# writing-->write
# writes-->write
# programming-->program
# programs-->program
# history-->histori

# %%
snow_stemmer.stem("fairly")
# Out:
# 'fair'

# %%
stemming.stem("fairly")
# Out:
# 'fairli'
