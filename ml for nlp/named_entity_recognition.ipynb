# %%
sentence="The Eiifel Tower was built by French engineer Gustave Eiifel in 1889."

# %%
import nltk
words=nltk.word_tokenize(sentence)
tagged=nltk.pos_tag(words)
print(tagged)
# Out:
# [('The', 'DT'), ('Eiifel', 'NNP'), ('Tower', 'NNP'), ('was', 'VBD'), ('built', 'VBN'), ('by', 'IN'), ('French', 'JJ'), ('engineer', 'NN'), ('Gustave', 'NNP'), ('Eiifel', 'NNP'), ('in', 'IN'), ('1889', 'CD'), ('.', '.')]

# %%
nltk.ne_chunk(tagged).draw()
